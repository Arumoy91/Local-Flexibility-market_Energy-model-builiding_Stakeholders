# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Prosumer energy consumption data Prediction.csv')
df
# Out:
#       Simple_Building_Energy_Rating Weather_File  Building_Type  \
# 0                                 D         2030  Semi Detached
# 1                                 D         2030       Terraced
# 2                                 A   Historical       Terraced
# 3                                 C   Historical       Terraced
# 4                                 E         2030       Terraced
# ...                             ...          ...            ...
# 39649                             A         2030       Bungalow
# 39650                             C   Historical       Bungalow
# 39651                             B   Historical       Detached
# 39652                             B   Historical       Terraced
# 39653                             E   Historical  Semi Detached
#
#       Renewable_Energy_Usage  Floor_Insulation_U-Value  \
# 0                        Yes                      0.55
# 1                        Yes                      0.30
# ...

# %%
df.head()
# Out:
#   Simple_Building_Energy_Rating Weather_File  Building_Type  \
# 0                             D         2030  Semi Detached
# 1                             D         2030       Terraced
# 2                             A   Historical       Terraced
# 3                             C   Historical       Terraced
# 4                             E         2030       Terraced
#
#   Renewable_Energy_Usage  Floor_Insulation_U-Value  Door_Insulation_U-Value  \
# 0                    Yes                      0.55                     3.98
# 1                    Yes                      0.30                     3.98
# 2                    Yes                      0.40                     3.00
# 3                    Yes                      0.80                     2.94
# 4                    Yes                      0.36                     1.50
#
#    Roof_Insulation_U-Value  Window_Insulation_U-Value  \
# 0                     2.13                       0.73
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39654 entries, 0 to 39653
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Simple_Building_Energy_Rating          39654 non-null  object
#  1   Weather_File                           39654 non-null  object
#  2   Building_Type                          39654 non-null  object
#  3   Renewable_Energy_Usage                 39654 non-null  object
#  4   Floor_Insulation_U-Value               39654 non-null  float64
#  5   Door_Insulation_U-Value                39654 non-null  float64
#  6   Roof_Insulation_U-Value                39654 non-null  float64
#  7   Window_Insulation_U-Value              39654 non-null  float64
#  8   Wall_Insulation_U-Value                39654 non-null  float64
#  9   Building_Energy_Rating                 39654 non-null  object
# ...

# %%
df.shape
# Out:
# (39654, 32)

# %%
df.columns
# Out:
# Index(['Simple_Building_Energy_Rating', 'Weather_File', 'Building_Type',
#        'Renewable_Energy_Usage', 'Floor_Insulation_U-Value',
#        'Door_Insulation_U-Value', 'Roof_Insulation_U-Value',
#        'Window_Insulation_U-Value', 'Wall_Insulation_U-Value',
#        'Building_Energy_Rating', 'HVAC_Efficiency', 'Domestic_Hot_Water_Usage',
#        'Building_Orientation', 'Lighting_Density', 'Occupancy_Level',
#        'Equipment_Density', 'Heating_Setpoint_Temperature',
#        'Heating_Setback_Temperature', 'Air_Change_Rate',
#        'Window_to_Wall_Ratio', 'Total_Building_Area', 'Heating_Usage',
#        'Water_Systems_Energy', 'Interior_Lighting_Energy',
#        'Interior_Equipment_Energy', 'Total_Heating_Energy',
#        'Photovoltaic_Power', 'Total_Electricity_Energy',
#        'Heating_Conversion_Factor', 'Electricity_Primary_Conversion_Factor',
#        'Heating_Primary_Conversion_Factor', 'Energy_Use_Intensity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Simple_Building_Energy_Rating             object
# Weather_File                              object
# Building_Type                             object
# Renewable_Energy_Usage                    object
# Floor_Insulation_U-Value                 float64
# Door_Insulation_U-Value                  float64
# Roof_Insulation_U-Value                  float64
# Window_Insulation_U-Value                float64
# Wall_Insulation_U-Value                  float64
# Building_Energy_Rating                    object
# HVAC_Efficiency                          float64
# Domestic_Hot_Water_Usage                 float64
# Building_Orientation                       int64
# Lighting_Density                           int64
# Occupancy_Level                            int64
# Equipment_Density                          int64
# Heating_Setpoint_Temperature               int64
# Heating_Setback_Temperature                int64
# Air_Change_Rate                          float64
# ...

# %%
df.describe()
# Out:
#        Floor_Insulation_U-Value  Door_Insulation_U-Value  \
# count              39654.000000             39654.000000
# mean                   0.338415                 2.048741
# std                    0.266256                 1.387358
# min                    0.150000                 0.810000
# 25%                    0.160000                 1.010000
# 50%                    0.250000                 1.500000
# 75%                    0.400000                 2.940000
# max                    1.600000                 5.700000
#
#        Roof_Insulation_U-Value  Window_Insulation_U-Value  \
# count             39654.000000               39654.000000
# mean                  0.740233                   2.189161
# std                   0.729863                   1.567835
# min                   0.070000                   0.730000
# 25%                   0.100000                   0.910000
# 50%                   0.400000                   1.620000
# ...

# %%
df.isnull().sum()
# Out:
# Simple_Building_Energy_Rating            0
# Weather_File                             0
# Building_Type                            0
# Renewable_Energy_Usage                   0
# Floor_Insulation_U-Value                 0
# Door_Insulation_U-Value                  0
# Roof_Insulation_U-Value                  0
# Window_Insulation_U-Value                0
# Wall_Insulation_U-Value                  0
# Building_Energy_Rating                   0
# HVAC_Efficiency                          0
# Domestic_Hot_Water_Usage                 0
# Building_Orientation                     0
# Lighting_Density                         0
# Occupancy_Level                          0
# Equipment_Density                        0
# Heating_Setpoint_Temperature             0
# Heating_Setback_Temperature              0
# Air_Change_Rate                          0
# Window_to_Wall_Ratio                     0
# Total_Building_Area                      0
# Heating_Usage                            0
# ...

# %%
dfcorr=df.corr()
dfcorr
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1160\3531566860.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcorr=df.corr()
#                                        Floor_Insulation_U-Value  \
# Floor_Insulation_U-Value                               1.000000
# Door_Insulation_U-Value                                0.282131
# Roof_Insulation_U-Value                                0.319803
# Window_Insulation_U-Value                              0.292145
# Wall_Insulation_U-Value                                0.298084
# HVAC_Efficiency                                       -0.279400
# Domestic_Hot_Water_Usage                               0.281207
# Building_Orientation                                   0.316036
# Lighting_Density                                       0.171709
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),cmap='summer')
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1160\3542323131.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='summer')
# <Axes: >

# %%
sns.countplot(x='Building_Type',data=df)
# Out:
# <Axes: xlabel='Building_Type', ylabel='count'>

# %%
building_type_counts = df['Building_Type'].value_counts()

# %%
building_type_counts
# Out:
# Bungalow         10670
# Semi Detached     9832
# Detached          9689
# Terraced          9463
# Name: Building_Type, dtype: int64

# %%
sns.boxplot(x=df['Energy_Use_Intensity'])
plt.xlabel('Energy_Use_Intensity')
plt.title('Box Plot of Energy_Use_Intensity')
plt.show()

# %%
sns.distplot(x=df['Total_Electricity_Energy'])
plt.xlabel('Total_Electricity_Energy')
plt.title('Box Plot of Total_Electricity_Energy')
plt.show()
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1160\374480766.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Total_Electricity_Energy'])

# %%
sns.histplot(x=df['Total_Heating_Energy'],bins=5)
plt.xlabel('Total_Heating_Energy')
plt.title('Box Plot of Total_Heating_Energy')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head()
# Out:
#    Simple_Building_Energy_Rating  Weather_File  Building_Type  \
# 0                              3             0              2
# 1                              3             0              3
# 2                              0             1              3
# 3                              2             1              3
# 4                              4             0              3
#
#    Renewable_Energy_Usage  Floor_Insulation_U-Value  Door_Insulation_U-Value  \
# 0                       0                      0.55                     3.98
# 1                       0                      0.30                     3.98
# 2                       0                      0.40                     3.00
# 3                       0                      0.80                     2.94
# 4                       0                      0.36                     1.50
#
#    Roof_Insulation_U-Value  Window_Insulation_U-Value  \
# 0                     2.13                       0.73
# ...

# %%
sns.distplot(df.Heating_Usage)
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1160\244040585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Heating_Usage)
# <Axes: xlabel='Heating_Usage', ylabel='Density'>

# %%
y = df.Energy_Use_Intensity
X = df.drop(["Energy_Use_Intensity"],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=25)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (39629, 31)
# (39629,)
# (25, 31)
# (25,)

# %%
from sklearn.linear_model import LinearRegression

# %%
ln = LinearRegression()

# %%
ln.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
training_data_prediction = ln.predict(X_train)
training_data_prediction
# Out:
# array([294.78777818, 105.91331373, 105.43361928, ..., 284.28027992,
#        342.26387354,  33.08783813])

# %%
y_pred=ln.predict(X_test)
y_pred
# Out:
# array([105.22440908, 176.06641962, 349.18091416, 293.33264491,
#        343.88084512,  36.04342255,  98.32946671,  28.9392168 ,
#        495.00063305, 441.59315146, 183.62590858, 217.40038103,
#         26.65596712,  98.7530439 , 181.96614999, 504.6642308 ,
#        268.28267019,  34.87758172, 341.27596272, 343.93988267,
#        108.51821156, 104.96779129, 258.14382197,  36.88977805,
#        190.32723247])

# %%
ln.score(X_test,y_test)
# Out:
# 0.9803600378398644

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE: 19.884951981636743

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 395.411315311999

# %%
print("R-Squared:",r2_score(y_test,y_pred))
# Out:
# R-Squared: 0.9803600378398644

# %%
print( ln.intercept_ )
# Out:
# 48.238583847249714

# %%
print( ln.coef_ )
# Out:
# [ 5.59272710e+01  1.31068507e+00 -1.01438004e+00 -5.16322263e-11
#  -3.51094844e+00 -7.67543182e-01 -2.24304995e+00 -3.30713588e-01
#  -1.79452115e+00  2.55178982e+00 -5.38772140e+00 -1.15783670e+00
#  -9.03885651e-03  5.47597500e-01 -4.26111948e-01  2.49737514e-01
#   8.25796804e-01 -3.21915501e-01  1.08117146e+00  1.22438426e-03
#  -1.77518172e-01  3.35821755e+01 -3.35799123e+01  2.89489263e+02
#   2.89490799e+02 -3.35807617e+01 -2.75013489e+02 -2.89488492e+02
#   2.62915941e+01  1.03891542e-20 -2.57795176e+00]

# %%
from sklearn.metrics import mean_absolute_error


mae = mean_absolute_error(y_test, y_pred)

# Print the result
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Absolute Error (MAE): 16.814018583269615
