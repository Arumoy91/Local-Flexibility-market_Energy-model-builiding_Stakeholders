# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Cleaning & preprocessing ##

# %%
df = pd.read_csv('Dataset builiding blocks_updated.csv')

# %%
df.head()
# Out:
#   Simple_Building_Energy_Rating  Building_Type_Code  Building_Type  \
# 0                             D                   2  Semi Detached
# 1                             G                   2  Semi Detached
# 2                             D                   2  Semi Detached
# 3                             F                   1       Detached
# 4                             D                   3       Terraced
#
#    Binary Code REW_EN Renewable_Energy_Usage  Total_Building_Area  \
# 0                   1                    Yes               107.69
# 1                   0                     No               107.69
# 2                   0                     No               107.69
# 3                   0                     No               130.81
# 4                   1                    Yes                91.66
#
#    Heating_Usage  Total_Heating_Energy  Total_Electricity_Energy  \
# 0       27345.28              16963.95                  5671.575
# ...

# %%
df.shape
# Out:
# (65535, 10)

# %%
df.columns
# Out:
# Index(['Simple_Building_Energy_Rating', 'Building_Type_Code', 'Building_Type',
#        'Binary Code REW_EN', 'Renewable_Energy_Usage', 'Total_Building_Area',
#        'Heating_Usage', 'Total_Heating_Energy', 'Total_Electricity_Energy',
#        'Energy_Use_Intensity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Simple_Building_Energy_Rating     object
# Building_Type_Code                 int64
# Building_Type                     object
# Binary Code REW_EN                 int64
# Renewable_Energy_Usage            object
# Total_Building_Area              float64
# Heating_Usage                    float64
# Total_Heating_Energy             float64
# Total_Electricity_Energy         float64
# Energy_Use_Intensity             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Simple_Building_Energy_Rating  65535 non-null  object
#  1   Building_Type_Code             65535 non-null  int64
#  2   Building_Type                  65535 non-null  object
#  3   Binary Code REW_EN             65535 non-null  int64
#  4   Renewable_Energy_Usage         65535 non-null  object
#  5   Total_Building_Area            65535 non-null  float64
#  6   Heating_Usage                  65535 non-null  float64
#  7   Total_Heating_Energy           65535 non-null  float64
#  8   Total_Electricity_Energy       65535 non-null  float64
#  9   Energy_Use_Intensity           65535 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 5.0+ MB

# %%
df.isnull().sum() ##Checking null values in the dataset
# Out:
# Simple_Building_Energy_Rating    0
# Building_Type_Code               0
# Building_Type                    0
# Binary Code REW_EN               0
# Renewable_Energy_Usage           0
# Total_Building_Area              0
# Heating_Usage                    0
# Total_Heating_Energy             0
# Total_Electricity_Energy         0
# Energy_Use_Intensity             0
# dtype: int64

# %%
df.describe()
# Out:
#        Building_Type_Code  Binary Code REW_EN  Total_Building_Area  \
# count        65535.000000        65535.000000         65535.000000
# mean             1.462150            0.605081           103.522294
# std              1.127861            0.488837            17.372405
# min              0.000000            0.000000            85.910000
# 25%              0.000000            0.000000            85.910000
# 50%              1.000000            1.000000            91.660000
# 75%              2.000000            1.000000           107.690000
# max              3.000000            1.000000           130.810000
#
#        Heating_Usage  Total_Heating_Energy  Total_Electricity_Energy  \
# count   65535.000000          65535.000000              65535.000000
# mean    18372.614355          12414.235403               3739.361861
# std     13503.689410          12828.434934               2559.971149
# min       213.730000              0.000000               -690.260000
# ...

# %%
dfcorr=df.corr() ###Performing Coorelation
dfcorr
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1680\2244778846.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcorr=df.corr() ###Performing Coorelation
#                           Building_Type_Code  Binary Code REW_EN  \
# Building_Type_Code                  1.000000           -0.006590
# Binary Code REW_EN                 -0.006590            1.000000
# Total_Building_Area                 0.001102            0.009328
# Heating_Usage                       0.134147           -0.187023
# Total_Heating_Energy               -0.240992           -0.126457
# Total_Electricity_Energy            0.054033           -0.290193
# Energy_Use_Intensity                0.128637           -0.286169
#
#                           Total_Building_Area  Heating_Usage  \
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),cmap='summer')
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1680\3542323131.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='summer')
# <Axes: >

# %%
df.shape
# Out:
# (65535, 10)

# %%
sns.pairplot(df)

# %%
sns.countplot(x='Renewable_Energy_Usage',data=df)
# Out:
# <Axes: xlabel='Renewable_Energy_Usage', ylabel='count'>

# %%
Renewable_percent=round((df['Renewable_Energy_Usage'].value_counts().values[0]/65535*100))

# %%
print(df['Renewable_Energy_Usage'].value_counts()/65535*100)
# Out:
# Yes    60.508125
# No     39.491875
# Name: Renewable_Energy_Usage, dtype: float64

# %%
sns.countplot(x='Building_Type',data=df)
# Out:
# <Axes: xlabel='Building_Type', ylabel='count'>

# %%
building_type_percent=round((df['Building_Type'].value_counts().values[0]/65535*100))

# %%
print(df['Building_Type'].value_counts()/65535*100)
# Out:
# Bungalow         26.935225
# Semi Detached    24.672313
# Terraced         24.238956
# Detached         24.153506
# Name: Building_Type, dtype: float64

# %%
# Plot a histogram
plt.hist(df['Total_Electricity_Energy'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel('Total Electricity Energy')
plt.ylabel('Frequency')
plt.title('Histogram of Total Electricity Energy')
plt.show()

# %%
# Plot a kernel density estimate plot
sns.kdeplot(df['Total_Electricity_Energy'], shade=True)
plt.xlabel('Total Electricity Energy')
plt.ylabel('Density')
plt.title('Kernel Density Estimate Plot of Total Electricity Energy')
plt.show()
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_1680\156223436.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Total_Electricity_Energy'], shade=True)

# %%
# Clustered Bar Plot
sns.countplot(x='Building_Type', hue='Renewable_Energy_Usage', data=df)
plt.xlabel('Building Type')
plt.ylabel('Count')
plt.title('Renewable Energy Usage by Building Type')
plt.legend(title='Renewable Energy Usage')
plt.show()

# %%
# Box Plot
sns.boxplot(x='Simple_Building_Energy_Rating', y='Total_Heating_Energy', data=df)
plt.xlabel('Simple Building Energy Rating')
plt.ylabel('Total Heating Energy')
plt.title('Total Heating Energy by Simple Building Energy Rating')
plt.show()

# %%
# Violin Plot
sns.violinplot(x='Simple_Building_Energy_Rating', y='Total_Heating_Energy', data=df)
plt.xlabel('Simple Building Energy Rating')
plt.ylabel('Total Heating Energy')
plt.title('Total Heating Energy by Simple Building Energy Rating')
plt.show()

##White dot represents the median
## the thick grey bar represents the inter quartile range
## the thin grey line represents the rest(1.5x of interquartile range) of the distributions

# %%
# Boxen Plot
sns.boxenplot(x='Building_Type', y='Energy_Use_Intensity', data=df)
plt.xlabel('Building Type')
plt.ylabel('Energy Use Intensity')
plt.title('Energy Use Intensity by Building Type')
plt.show()

# %%
# Plot a box plot to understand the energy intensity
sns.boxplot(x=df['Energy_Use_Intensity'])
plt.xlabel('Energy_Use_Intensity')
plt.title('Box Plot of Energy_Use_Intensity')
plt.show()

# %%
# Boxplot or Violin Plot by Building Type
sns.boxplot(x='Building_Type', y='Energy_Use_Intensity', data=df)
plt.xlabel('Building Type')
plt.ylabel('Energy Use Intensity')
plt.title('Energy Use Intensity by Building Type')
plt.show()

# %%
df['Energy_Use_Intensity'].describe()
# Out:
# count    65535.000000
# mean       242.336402
# std        148.511680
# min         -6.406363
# 25%        118.451068
# 50%        225.452250
# 75%        333.476575
# max        649.999437
# Name: Energy_Use_Intensity, dtype: float64

# %%
# Scatter Plot
plt.scatter(df['Total_Building_Area'], df['Total_Heating_Energy'])
plt.xlabel('Total Building Area')
plt.ylabel('Total Heating Energy')
plt.title('Total Heating Energy vs. Total Building Area')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head()
# Out:
#    Simple_Building_Energy_Rating  Building_Type_Code  Building_Type  \
# 0                              3                   2              2
# 1                              6                   2              2
# 2                              3                   2              2
# 3                              5                   1              1
# 4                              3                   3              3
#
#    Binary Code REW_EN  Renewable_Energy_Usage  Total_Building_Area  \
# 0                   1                       1               107.69
# 1                   0                       0               107.69
# 2                   0                       0               107.69
# 3                   0                       0               130.81
# 4                   1                       1                91.66
#
#    Heating_Usage  Total_Heating_Energy  Total_Electricity_Energy  \
# 0       27345.28              16963.95                  5671.575
# ...

# %%
df.head(10)
# Out:
#    Simple_Building_Energy_Rating  Building_Type_Code  Building_Type  \
# 0                              3                   2              2
# 1                              6                   2              2
# 2                              3                   2              2
# 3                              5                   1              1
# 4                              3                   3              3
# 5                              2                   0              0
# 6                              4                   1              1
# 7                              3                   0              0
# 8                              0                   3              3
# 9                              2                   3              3
#
#    Binary Code REW_EN  Renewable_Energy_Usage  Total_Building_Area  \
# 0                   1                       1               107.69
# 1                   0                       0               107.69
# ...

# %%
df.shape
# Out:
# (65535, 10)

# %%
df.head()
# Out:
#    Simple_Building_Energy_Rating  Building_Type_Code  Building_Type  \
# 0                              3                   2              2
# 1                              6                   2              2
# 2                              3                   2              2
# 3                              5                   1              1
# 4                              3                   3              3
#
#    Binary Code REW_EN  Renewable_Energy_Usage  Total_Building_Area  \
# 0                   1                       1               107.69
# 1                   0                       0               107.69
# 2                   0                       0               107.69
# 3                   0                       0               130.81
# 4                   1                       1                91.66
#
#    Heating_Usage  Total_Heating_Energy  Total_Electricity_Energy  \
# 0       27345.28              16963.95                  5671.575
# ...

# %%
df.head(10)
# Out:
#    Simple_Building_Energy_Rating  Building_Type_Code  Building_Type  \
# 0                              3                   2              2
# 1                              6                   2              2
# 2                              3                   2              2
# 3                              5                   1              1
# 4                              3                   3              3
# 5                              2                   0              0
# 6                              4                   1              1
# 7                              3                   0              0
# 8                              0                   3              3
# 9                              2                   3              3
#
#    Binary Code REW_EN  Renewable_Energy_Usage  Total_Building_Area  \
# 0                   1                       1               107.69
# 1                   0                       0               107.69
# ...

# %%
df.drop(columns=['Binary Code REW_EN'], inplace=True)
df.drop(columns=['Building_Type_Code'], inplace=True)
df.drop(columns=['Simple_Building_Energy_Rating'], inplace=True)

# %%
X=df.drop(['Renewable_Energy_Usage'], axis=1)
y=df['Renewable_Energy_Usage']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.30,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize logistic regression model
logistic_model = LogisticRegression()

# Train the model on the transformed training data
logistic_model.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = logistic_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6411677941101673
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48      7767
#            1       0.67      0.79      0.73     11894
#
#     accuracy                           0.64     19661
#    macro avg       0.62      0.60      0.60     19661
# weighted avg       0.63      0.64      0.63     19661

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
ad=AdaBoostClassifier()

# %%
ad.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = ad.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7167997558618585
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.68      0.65      7767
#            1       0.78      0.74      0.76     11894
#
#     accuracy                           0.72     19661
#    macro avg       0.71      0.71      0.71     19661
# weighted avg       0.72      0.72      0.72     19661

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.68      0.65      7767
#            1       0.78      0.74      0.76     11894
#
#     accuracy                           0.72     19661
#    macro avg       0.71      0.71      0.71     19661
# weighted avg       0.72      0.72      0.72     19661

# %%
cm=confusion_matrix(y_test,ad.predict(X_test))

# %%
print(cm)
# Out:
# [[5249 2518]
#  [3050 8844]]

# %%
Ra=RandomForestClassifier()

# %%
Ra.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = Ra.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9252326941661156
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      7767
#            1       0.94      0.93      0.94     11894
#
#     accuracy                           0.93     19661
#    macro avg       0.92      0.92      0.92     19661
# weighted avg       0.93      0.93      0.93     19661

# %%
cm=confusion_matrix(y_test,Ra.predict(X_test))

# %%
print(cm)
# Out:
# [[ 7116   651]
#  [  819 11075]]

# %%
gnb=GaussianNB()

# %%
gnb.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = gnb.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6304358883068003
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.47      0.50      7767
#            1       0.68      0.73      0.71     11894
#
#     accuracy                           0.63     19661
#    macro avg       0.61      0.60      0.60     19661
# weighted avg       0.62      0.63      0.63     19661

# %%
kc=KNeighborsClassifier()

# %%
kc.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = kc.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6423884848176593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.52      0.54      7767
#            1       0.70      0.72      0.71     11894
#
#     accuracy                           0.64     19661
#    macro avg       0.62      0.62      0.62     19661
# weighted avg       0.64      0.64      0.64     19661

# %%
ga= GradientBoostingClassifier()

# %%
ga.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = ga.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8679110930268044
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82      7767
#            1       0.86      0.93      0.90     11894
#
#     accuracy                           0.87     19661
#    macro avg       0.87      0.85      0.86     19661
# weighted avg       0.87      0.87      0.87     19661

# %%
et=ExtraTreesClassifier()

# %%
et.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = et.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8428360714104064
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80      7767
#            1       0.88      0.86      0.87     11894
#
#     accuracy                           0.84     19661
#    macro avg       0.83      0.84      0.84     19661
# weighted avg       0.84      0.84      0.84     19661

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, y_pred, pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, y_pred, pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, y_pred)
auc_score2 = roc_auc_score(y_test, y_pred)

print(auc_score1, auc_score2)
# Out:
# 0.8388532255948099 0.8388532255948099

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Calculate AUC-ROC score
auc_roc_score = roc_auc_score(y_test, y_pred)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % auc_roc_score)
plt.plot([0, 1], [0, 1], color='green', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
